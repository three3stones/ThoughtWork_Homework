# %%
"""
任务：
1. 通过花的属性数据预测花的种类,尝试构建决策树模型,要求最大树深度为3
2. 尝试预测sepal length=6,sepal width=1,petal length=3,petal width=1最可能是什么类型的花
3. 可视化决策树,解释下什么样的花最可能是setosa
"""

# %%
# 引入数据
import pandas as pd
from sklearn import datasets
X,y = datasets.load_iris(return_X_y=True)          # X与y
target_names = datasets.load_iris().target_names   # y的值列表:0:setosa,1:versicolor,2:virginica
feature_names = datasets.load_iris().feature_names  # 特征X的名称列表

# %%
# 1. 建立决策树模型
from sklearn import tree
clf = tree.DecisionTreeClassifier(max_depth=3)
clf = clf.fit(X, y)

# %%
# 2. 使用决策树模型预测样本类别
print(clf.predict([[6., 1., 3., 1.]]))
print(clf.predict_proba([[6., 1., 3., 1.]]))
# Out:
# [1]
# [[0.         0.97916667 0.02083333]]

# %% [markdown]
# ### 2. 从预测的概率来说，该样本最可能是类型1-versicolor品种的花

# %%
# 3. 决策树模型可视化
import graphviz
import pydotplus
import os
os.environ["PATH"] += os.pathsep + 'F:/Anaconda/graphViz/Graphviz 2.44.1/bin/'    # 指定graphviz的安装位置
from IPython.display import Image
dot_tree = tree.export_graphviz(clf,out_file=None,feature_names=feature_names,class_names=target_names,filled=True, rounded=True,special_characters=True)
graph = pydotplus.graph_from_dot_data(dot_tree)
Image(graph.create_png())

# %% [markdown]
# ### 3. 从决策树逻辑中可以看出，花的属性 petal width<=0.8 时，最可能是setosa种类
